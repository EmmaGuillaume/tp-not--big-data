# %% [markdown]
# # Part 2

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import re
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Création de la session Spark
spark = SparkSession.builder \
    .appName("Apache Log Analysis - Local Mode") \
    .master("local[*]") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

# Réduire la verbosité des logs
spark.sparkContext.setLogLevel("WARN")

print(f"Spark version: {spark.version}")
print(f"Spark master: {spark.sparkContext.master}")

# %%
# import des données
hdfs_path = "../data/access.log"  

logs_raw = spark.read.text(hdfs_path)

logs_raw.count()
# Out:
# 3602

# %%
logs_raw.show(5, truncate=False)

# %%
# transformation des logs en base
log_pattern = r'^(\S+) \S+ \S+ \[(.*?)\] "(\S+) (.*?) (HTTP/\S+)" (\d{3}) (\S+) "(.*?)" "(.*?)"'

logs_df = logs_raw.select(
    regexp_extract(col("value"), log_pattern, 1).alias("ip"),
    regexp_extract(col("value"), log_pattern, 2).alias("timestamp"),
    regexp_extract(col("value"), log_pattern, 3).alias("method"),
    regexp_extract(col("value"), log_pattern, 4).alias("url"),
    regexp_extract(col("value"), log_pattern, 6).cast("int").alias("status_code")
).filter(col("ip") != "")

logs_df.cache()

logs_df.printSchema()
logs_df.show(5, truncate=120)
# Out:
# root
#  |-- ip: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- status_code: integer (nullable = true)
#
# +---------------+--------------------------+------+--------------+-----------+
# |             ip|                 timestamp|method|           url|status_code|
# +---------------+--------------------------+------+--------------+-----------+
# |   57.70.252.24|01/Nov/2024:00:12:53 +0100|   GET|/products/P001|        404|
# |168.255.202.227|01/Nov/2024:00:13:40 +0100|   GET|          /faq|        200|
# |   109.16.15.24|01/Nov/2024:01:20:27 +0100|DELETE|      /contact|        200|
# | 161.81.216.153|01/Nov/2024:01:35:19 +0100|   GET|    /blog/news|        200|
# |  133.231.61.64|01/Nov/2024:01:37:51 +0100|   GET|    /blog/news|        404|
# +---------------+--------------------------+------+--------------+-----------+
# only showing top 5 rows

# %%
# ajout des colones calculées
logs_df = logs_df \
    .withColumn(
        "status_group",
        when(col("status_code").between(200, 299), "2xx")
        .when(col("status_code").between(400, 499), "4xx")
        .when(col("status_code").between(500, 599), "5xx")
        .otherwise("other")
    ) \
    .withColumn(
        "is_error",
        col("status_code") >= 400
    ) \
    .withColumn(
        "timestamp_parsed",
        to_timestamp(col("timestamp"), "dd/MMM/yyyy:HH:mm:ss Z")
    ) \
    .withColumn(
        "hour",
        hour(col("timestamp_parsed"))
    )

logs_df.select("status_code", "status_group", "is_error", "hour").show(5)

# %%
# création des profils suspects
profil_ip_df = logs_df.groupBy("ip").agg(
    
    count("*").alias("nb_requetes"),
    
    sum(when(col("is_error") == True, 1).otherwise(0)).alias("nb_erreurs"),
    
    sum(
        when(col("hour").between(1, 4), 1).otherwise(0)
    ).alias("nb_requetes_nuit")
)

profil_ip_df = profil_ip_df.withColumn(
    "taux_erreur",
    round(col("nb_erreurs") / col("nb_requetes"), 3)
)

profil_ip_df = profil_ip_df.select(
    "ip",
    "nb_requetes",
    "nb_erreurs",
    "taux_erreur",
    "nb_requetes_nuit"
)


profil_ip_df.show(5, truncate=False)

# %%
# vérification
df_check = spark.read \
    .format("mongodb") \
    .option("spark.mongodb.connection.uri", "mongodb://mongo-logs:27017") \
    .option("spark.mongodb.database", "logs_db") \
    .option("spark.mongodb.collection", "ip_profiles") \
    .load()

# %% [markdown]
# # Part 3

# %%
from pymongo import MongoClient
import json

client = MongoClient("mongodb://mongo-ecommerce:27017")
db = client["ecommerce_db"]

customers_col = db["customers"]
orders_col = db["orders"]

# %%
# ajout des clients
with open("/home/jovyan/work/data/clients.json", "r", encoding="utf-8") as f:
    clients_data = json.load(f)

customers_col.insert_many(clients_data)

print(f"{customers_col.count_documents({})} clients insérés")
# Out:
# 300 clients insérés

# %%
# ajout des commandes
with open("/home/jovyan/work/data/commandes.json", "r", encoding="utf-8") as f:
    commandes_data = json.load(f)

orders_col.insert_many(commandes_data)

print(f"{orders_col.count_documents({})} commandes insérées")
# Out:
# 844 commandes insérées

# %%
# ptite vérif des familles
print("Exemple client :", customers_col.find_one())
print("Exemple commande :", orders_col.find_one())
# Out:
# Exemple client : {'_id': ObjectId('6996da6a6e2e70ab018563ed'), 'client_id': 'C_0012', 'prenom': 'Maryse', 'nom': 'Muller', 'email': 'peltiermichel@example.com', 'ip_address': '23.201.187.4', 'ville': 'Saint Eugènenec', 'date_inscription': '2023-12-18', 'statut': 'actif'}
# Exemple commande : {'_id': ObjectId('6996dae268b14c7b63690078'), 'commande_id': 'CMD_00107', 'client_id': 'C_0093', 'date_commande': '2026-02-17T23:03:40.759704', 'statut': 'annulee', 'items': [{'produit_id': 'P001', 'nom_produit': 'Laptop Pro 15', 'quantite': 2, 'prix_unitaire': 1299.99, 'sous_total': 2599.98}, {'produit_id': 'P017', 'nom_produit': 'Routeur WiFi 6', 'quantite': 3, 'prix_unitaire': 179.0, 'sous_total': 537.0}], 'total': 3136.98}

# %%
# pipeline demandée
pipeline_total = [
    {"$unwind": "$items"},
    {"$group": {
        "_id": "$client_id",
        "total_depense": {"$sum": {"$multiply": ["$items.quantite", "$items.prix_unitaire"]}}
    }},
    {"$sort": {"total_depense": -1}}
]

total_par_client = list(orders.aggregate(pipeline_total))
for c in total_par_client[:10]:
    print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 10
#       1 pipeline_total = [
#       2     {"$unwind": "$items"},
#       3     {"$group": {
#    (...)
#       7     {"$sort": {"total_depense": -1}}
#       8 ]
# ---> 10 total_par_client = list(orders.aggregate(pipeline_total))
#      11 for c in total_par_client[:10]:
#      12     print(c)
#
# NameError: name 'orders' is not defined

# %%
pipeline_panier = [
    {"$unwind": "$items"},
    {"$group": {
        "_id": {"client_id": "$client_id", "order_id": "$_id"},
        "order_total": {"$sum": {"$multiply": ["$items.quantite", "$items.prix_unitaire"]}}
    }},
    {"$group": {
        "_id": "$_id.client_id",
        "panier_moyen": {"$avg": "$order_total"},
        "nb_commandes": {"$sum": 1}
    }},
    {"$sort": {"panier_moyen": -1}}
]

panier_par_client = list(orders.aggregate(pipeline_panier))
for c in panier_par_client[:10]:
    print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 15
#       1 pipeline_panier = [
#       2     {"$unwind": "$items"},
#       3     {"$group": {
#    (...)
#      12     {"$sort": {"panier_moyen": -1}}
#      13 ]
# ---> 15 panier_par_client = list(orders.aggregate(pipeline_panier))
#      16 for c in panier_par_client[:10]:
#      17     print(c)
#
# NameError: name 'orders' is not defined

# %%
pipeline_top3 = [
    {"$unwind": "$items"},
    {"$group": {
        "_id": "$items.produit_id",
        "total_quantite": {"$sum": "$items.quantite"}
    }},
    {"$sort": {"total_quantite": -1}},
    {"$limit": 3}
]

top3_produits = list(orders.aggregate(pipeline_top3))
for p in top3_produits:
    print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 11
#       1 pipeline_top3 = [
#       2     {"$unwind": "$items"},
#       3     {"$group": {
#    (...)
#       8     {"$limit": 3}
#       9 ]
# ---> 11 top3_produits = list(orders.aggregate(pipeline_top3))
#      12 for p in top3_produits:
#      13     print(p)
#
# NameError: name 'orders' is not defined

# %% [markdown]
# # Part 4

# %%
from cassandra.cluster import Cluster
from datetime import datetime
import json

cluster = Cluster(['tp_cassandra'])  
session = cluster.connect()

# %%
session.execute("""
CREATE KEYSPACE IF NOT EXISTS reporting_ecommerce
WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1};
""")

session.set_keyspace('reporting_ecommerce')

# %%
# clean et création des tables
session.execute("DROP TABLE IF EXISTS commandes_par_client")
session.execute("DROP TABLE IF EXISTS commandes_par_date")

session.execute("""
    CREATE TABLE IF NOT EXISTS commandes_par_client (
        client_id text,
        date_commande timestamp,
        commande_id text,
        statut text,
        items list<frozen<map<text,text>>>,
        total double,
        PRIMARY KEY (client_id, date_commande, commande_id)
    ) WITH CLUSTERING ORDER BY (date_commande DESC)
""")

session.execute("""
    CREATE TABLE IF NOT EXISTS commandes_par_date (
        date_commande date,
        commande_id text,
        client_id text,
        statut text,
        items list<frozen<map<text,text>>>,
        total double,
        PRIMARY KEY (date_commande, commande_id)
    ) WITH CLUSTERING ORDER BY (commande_id ASC)
""")

# %%
session.execute("DESCRIBE TABLE commandes_par_client")

# %%
#insertion des données
with open("/home/jovyan/work/data/commandes.json", "r", encoding="utf-8") as f:
    commandes = json.load(f)

for c in commandes:
    commande_id = c['commande_id']
    client_id = c['client_id']
    date_str = c['date_commande']
    date_commande = datetime.fromisoformat(date_str)
    statut = c['statut']

    items = [
        {
            "produit_id": str(i["produit_id"]),
            "nom_produit": str(i["nom_produit"]),
            "quantite": str(i["quantite"]),
            "prix_unitaire": str(i["prix_unitaire"]),
            "sous_total": str(i["sous_total"])
        }
        for i in c['items']
    ]


    total = c['total']
    session.execute(
        "INSERT INTO commandes_par_client (client_id, date_commande, commande_id, statut, items, total) VALUES (%s, %s, %s, %s, %s, %s)",
        [client_id, date_commande, commande_id, statut, items, total]
    )
    
    session.execute(
        "INSERT INTO commandes_par_date (date_commande, commande_id, client_id, statut, items, total) VALUES (%s, %s, %s, %s, %s, %s)",
        [date_commande.date(), commande_id, client_id, statut, items, total]
    )

# %%
# affichage pour vérifier
print("=== commandes_par_client ===")
rows = session.execute("SELECT * FROM commandes_par_client LIMIT 1")
for row in rows:
    print(row)

print(f"\n=== commandes_par_date ===")
rows = session.execute("SELECT * FROM commandes_par_date LIMIT 1")
for row in rows:
    print(row)

count1 = session.execute("SELECT COUNT(*) FROM commandes_par_client").one()[0]
count2 = session.execute("SELECT COUNT(*) FROM commandes_par_date").one()[0]
print(f"\nTotal commandes_par_client : {count1}")
print(f"Total commandes_par_date : {count2}")
# Out:
# === commandes_par_client ===
# Row(client_id='C_0044', date_commande=datetime.datetime(2026, 2, 17, 23, 5, 32, 29000), commande_id='CMD_00159', items=[OrderedMapSerializedKey([('nom_produit', 'Routeur WiFi 6'), ('prix_unitaire', '179.0'), ('produit_id', 'P017'), ('quantite', '3'), ('sous_total', '537.0')]), OrderedMapSerializedKey([('nom_produit', 'Clavier mécanique'), ('prix_unitaire', '89.9'), ('produit_id', 'P003'), ('quantite', '2'), ('sous_total', '179.8')]), OrderedMapSerializedKey([('nom_produit', 'Tapis de souris XL'), ('prix_unitaire', '24.9'), ('produit_id', 'P014'), ('quantite', '3'), ('sous_total', '74.7')])], statut='livree', total=791.5)
#
# === commandes_par_date ===
# ...

# %% [markdown]
# Pour la table `commandes_par_client`, nous avons choisi `client_id` comme clé de partition pour regrouper toutes les commandes d’un même client. La colonne de clustering est `date_commande` en ordre décroissant afin de voir les commandes les plus récentes en premier. Cela permet de répondre rapidement à la requête sur l’historique des commandes d’un client. Pour la table commandes_par_date, la clé de partition est `date_commande` pour rassembler toutes les commandes d’un même jour, et la colonne de clustering est `commande_id pour distinguer les différentes commandes de la journée. Cette structure facilite la récupération des commandes par date.
